# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
import torch

# %%
train = pd.read_csv('./dataset/train_pre.csv')

# %%
train.shape
# Out:
# (12692, 548)

# %%
test = pd.read_csv('./dataset/test.csv')

# %%
test.shape
# Out:
# (3929, 390)

# %%
train.head(1)
# Out:
#    PRODUCT_ID STORE_ID BONUS_BUY_NOTE  COUNT_WKD  HOLIDAY_COUNT  \
# 0    10624352     3770           A001          4              1
#
#    OPENING_STOCK_QUANTITY  NUMBER_OF_OOS  NORMAL_PRICE  PROMOTION_PRICE  \
# 0                     7.0              0      119000.0          89000.0
#
#    NORMAL_SALE_RATE  ...              conditions  limited_offer  \
# 0          0.066667  ...  Rain, Partially cloudy              1
#
#    price_difference  store_popularity  product_popularity  bonuses_popularity  \
# 0           30000.0              0.44            0.391139            0.391139
#
#    rolling_mean_PROMOTION_QTY  avg_promo_qty_by_store  \
# 0                         2.0                5.810358
#
#    avg_promo_qty_by_product  stock_to_sales_ratio
# 0                  1.559524                   6.0
#
# [1 rows x 33 columns]

# %%
CAT_COLS = ['PRODUCT_ID','STORE_ID', "BONUS_BUY_NOTE","conditions"]

# %%
def one_hot_encode(df, columns):
    """
    Perform one-hot encoding on specified columns in a DataFrame.
    
    """
    # Perform one-hot encoding using pd.get_dummies
    df_encoded = pd.get_dummies(df, columns=columns, drop_first=True)
    
    return df_encoded

# %%
train = one_hot_encode(train,CAT_COLS)

# %%
test = one_hot_encode(test,CAT_COLS)

# %%
train.head(1)
# Out:
#    COUNT_WKD  HOLIDAY_COUNT  OPENING_STOCK_QUANTITY  NUMBER_OF_OOS  \
# 0          4              1                     7.0              0
#
#    NORMAL_PRICE  PROMOTION_PRICE  NORMAL_SALE_RATE  NORMAL_SALE_RATE_30D  \
# 0      119000.0          89000.0          0.066667              0.133333
#
#    PROMOTION_SALE_RATE  MIN_PROMOTION_SALE_QTY  ...  BONUS_BUY_NOTE_A007  \
# 0             0.066667                     1.0  ...                False
#
#    BONUS_BUY_NOTE_A011  BONUS_BUY_NOTE_A018  BONUS_BUY_NOTE_A023  \
# 0                False                False                False
#
#    BONUS_BUY_NOTE_A024  BONUS_BUY_NOTE_A032  BONUS_BUY_NOTE_A033  \
# 0                False                False                False
#
#    BONUS_BUY_NOTE_A999  conditions_Partially cloudy  \
# 0                False                        False
#
#    conditions_Rain, Partially cloudy
# 0                               True
#
# [1 rows x 548 columns]

# %%
# train['PROMOTION_QTY']

# %%
X_train, y_train = train.drop(['PROMOTION_QTY'],axis=1), train['PROMOTION_QTY']
X_test, y_test = test.drop(['PROMOTION_QTY'],axis=1), test['PROMOTION_QTY']

# %%
len(train)
# Out:
# 12692

# %%
train.shape
# Out:
# (12692, 548)

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 3060 Laptop GPU'

# %%
## Model training
model = XGBRegressor(tree_method="hist", device="cuda", enable_categorical=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %%time
model.fit(X_train,y_train)
# Out:
# CPU times: total: 3.47 s
# Wall time: 3.24 s
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model.score(X_test,y_test)
#
# File ~\anaconda3\envs\ocr_env\lib\site-packages\sklearn\base.py:848, in RegressorMixin.score(self, X, y, sample_weight)
#     806 """Return the coefficient of determination of the prediction.
#     807
#     808 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     843 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     844 """
#     846 from .metrics import r2_score
# --> 848 y_pred = self.predict(X)
#     849 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\anaconda3\envs\ocr_env\lib\site-packages\xgboost\sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File ~\anaconda3\envs\ocr_env\lib\site-packages\xgboost\core.py:2510, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2508     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2509     if validate_features:
# -> 2510         self._validate_features(fns)
#    2511 if _is_list(data) or _is_tuple(data):
#    2512     data = np.array(data)
#
# File ~\anaconda3\envs\ocr_env\lib\site-packages\xgboost\core.py:3075, in Booster._validate_features(self, feature_names)
#    3069 if my_missing:
#    3070     msg += (
#    3071         "\ntraining data did not have the following fields: "
#    3072         + ", ".join(str(s) for s in my_missing)
#    3073     )
# -> 3075 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['COUNT_WKD', 'HOLIDAY_COUNT', 'OPENING_STOCK_QUANTITY', 'NUMBER_OF_OOS', 'NORMAL_PRICE', 'PROMOTION_PRICE', 'NORMAL_SALE_RATE', 'NORMAL_SALE_RATE_30D', 'PROMOTION_SALE_RATE', 'MIN_PROMOTION_SALE_QTY', 'MAX_PROMOTION_SALE_QTY', 'PROMOTION_UPLIFT', 'PROMOTIONAL_DEMAND', 'DELTA_QTY', 'DELTA_PRICE', 'PRICE_ELASTICITY_OF_DEMAND', 'discount_pct', 'daily_avg_inventory', 'total_zero_inv_days', 'limited_offer', 'price_difference', 'store_popularity', 'product_popularity', 'bonuses_popularity', 'rolling_mean_PROMOTION_QTY', 'avg_promo_qty_by_store', 'avg_promo_qty_by_product', 'stock_to_sales_ratio', 'PRODUCT_ID_10007821', 'PRODUCT_ID_10007824', 'PRODUCT_ID_10007834', 'PRODUCT_ID_10007837', 'PRODUCT_ID_10007893', 'PRODUCT_ID_10007896', 'PRODUCT_ID_10007902', 'PRODUCT_ID_10007925', 'PRODUCT_ID_10007927', 'PRODUCT_ID_10007928', 'PRODUCT_ID_10007930', 'PRODUCT_ID_10007935', 'PRODUCT_ID_10007936', 'PRODUCT_ID_10007945', 'PRODUCT_ID_10007951', 'PRODUCT_ID_10007952', 'PRODUCT_ID_10007953', 'PRODUCT_ID_10007955', 'PRODUCT_ID_10007957', 'PRODUCT_ID_10007958', 'PRODUCT_ID_10007960', 'PRODUCT_ID_10007961', 'PRODUCT_ID_10007963', 'PRODUCT_ID_10007964', 'PRODUCT_ID_10007983', 'PRODUCT_ID_10007984', 'PRODUCT_ID_10007985', 'PRODUCT_ID_10008050', 'PRODUCT_ID_10008051', 'PRODUCT_ID_10008053', 'PRODUCT_ID_10008082', 'PRODUCT_ID_10008607', 'PRODUCT_ID_10008624', 'PRODUCT_ID_10008681', 'PRODUCT_ID_10008683', 'PRODUCT_ID_10008690', 'PRODUCT_ID_10008696', 'PRODUCT_ID_10008740', 'PRODUCT_ID_10008782', 'PRODUCT_ID_10009041', 'PRODUCT_ID_10009044', 'PRODUCT_ID_10009085', 'PRODUCT_ID_10009165', 'PRODUCT_ID_10009213', 'PRODUCT_ID_10009244', 'PRODUCT_ID_10009550', 'PRODUCT_ID_10009687', 'PRODUCT_ID_10010065', 'PRODUCT_ID_10010066', 'PRODUCT_ID_10010072', 'PRODUCT_ID_10010073', 'PRODUCT_ID_10010076', 'PRODUCT_ID_10010079', 'PRODUCT_ID_10010116', 'PRODUCT_ID_10010117', 'PRODUCT_ID_10010151', 'PRODUCT_ID_10010158', 'PRODUCT_ID_10011145', 'PRODUCT_ID_10011147', 'PRODUCT_ID_10011210', 'PRODUCT_ID_10011392', 'PRODUCT_ID_10011393', 'PRODUCT_ID_10011400', 'PRODUCT_ID_10011433', 'PRODUCT_ID_10011506', 'PRODUCT_ID_10011747', 'PRODUCT_ID_10011788', 'PRODUCT_ID_10012008', 'PRODUCT_ID_10012012', 'PRODUCT_ID_10012822', 'PRODUCT_ID_10012913', 'PRODUCT_ID_10012920', 'PRODUCT_ID_10012923', 'PRODUCT_ID_10012928', 'PRODUCT_ID_10013011', 'PRODUCT_ID_10013052', 'PRODUCT_ID_10013259', 'PRODUCT_ID_10013306', 'PRODUCT_ID_10013397', 'PRODUCT_ID_10013465', 'PRODUCT_ID_10013471', 'PRODUCT_ID_10013501', 'PRODUCT_ID_10013503', 'PRODUCT_ID_10013504', 'PRODUCT_ID_10013560', 'PRODUCT_ID_10013655', 'PRODUCT_ID_10013657', 'PRODUCT_ID_10013658', 'PRODUCT_ID_10013659', 'PRODUCT_ID_10013764', 'PRODUCT_ID_10013795', 'PRODUCT_ID_10013811', 'PRODUCT_ID_10013857', 'PRODUCT_ID_10013858', 'PRODUCT_ID_10013863', 'PRODUCT_ID_10013881', 'PRODUCT_ID_10013932', 'PRODUCT_ID_10013935', 'PRODUCT_ID_10013979', 'PRODUCT_ID_10013980', 'PRODUCT_ID_10014231', 'PRODUCT_ID_10014498', 'PRODUCT_ID_10014499', 'PRODUCT_ID_10014529', 'PRODUCT_ID_10014530', 'PRODUCT_ID_10014861', 'PRODUCT_ID_10015010', 'PRODUCT_ID_10015011', 'PRODUCT_ID_10015255', 'PRODUCT_ID_10015596', 'PRODUCT_ID_10015597', 'PRODUCT_ID_10015740', 'PRODUCT_ID_10015748', 'PRODUCT_ID_10015752', 'PRODUCT_ID_10015753', 'PRODUCT_ID_10016022', 'PRODUCT_ID_10016730', 'PRODUCT_ID_10016738', 'PRODUCT_ID_10016739', 'PRODUCT_ID_10016762', 'PRODUCT_ID_10016763', 'PRODUCT_ID_10016785', 'PRODUCT_ID_10016800', 'PRODUCT_ID_10016836', 'PRODUCT_ID_10016842', 'PRODUCT_ID_10016850', 'PRODUCT_ID_10016910', 'PRODUCT_ID_10017001', 'PRODUCT_ID_10017158', 'PRODUCT_ID_10017422', 'PRODUCT_ID_10017423', 'PRODUCT_ID_10017425', 'PRODUCT_ID_10017513', 'PRODUCT_ID_10017534', 'PRODUCT_ID_10017861', 'PRODUCT_ID_10017862', 'PRODUCT_ID_10017864', 'PRODUCT_ID_10017918', 'PRODUCT_ID_10018163', 'PRODUCT_ID_10018429', 'PRODUCT_ID_10018729', 'PRODUCT_ID_10018730', 'PRODUCT_ID_10018755', 'PRODUCT_ID_10018953', 'PRODUCT_ID_10018975', 'PRODUCT_ID_10019675', 'PRODUC ...
# expected PRODUCT_ID_10602568, PRODUCT_ID_10162292, PRODUCT_ID_10628248, PRODUCT_ID_10142275, PRODUCT_ID_10617338, PRODUCT_ID_10290008, PRODUCT_ID_10142324, PRODUCT_ID_10622362, PRODUCT_ID_10013560, PRODUCT_ID_10142002, PRODUCT_ID_10170855, PRODUCT_ID_10197302, PRODUCT_ID_10600006, PRODUCT_ID_10162324, PRODUCT_ID_10018730, PRODUCT_ID_10018729, PRODUCT_ID_10010116, PRODUCT_ID_10142274, PRODUCT_ID_10019906, PRODUCT_ID_10008782, PRODUCT_ID_10632693, PRODUCT_ID_10195096, PRODUCT_ID_10197446, PRODUCT_ID_10171159, PRODUCT_ID_10170836, PRODUCT_ID_10181100, PRODUCT_ID_10327500, PRODUCT_ID_10197076, PRODUCT_ID_10197523, PRODUCT_ID_10015740, PRODUCT_ID_10196847, PRODUCT_ID_10007951, PRODUCT_ID_10614963, PRODUCT_ID_10602562, PRODUCT_ID_10010151, PRODUCT_ID_10013011, PRODUCT_ID_10014529, PRODUCT_ID_10014499, PRODUCT_ID_10171202, PRODUCT_ID_10181025, PRODUCT_ID_10013471, PRODUCT_ID_10017423, PRODUCT_ID_10142325, PRODUCT_ID_10625389, PRODUCT_ID_10013655, PRODUCT_ID_10316597, PRODUCT_ID_10150487, PRODUCT_ID_10009244, PRODUCT_ID_10251279, PRODUCT_ID_10017861, PRODUCT_ID_10195647, PRODUCT_ID_10013501, PRODUCT_ID_10010073, PRODUCT_ID_10015010, PRODUCT_ID_10621537, PRODUCT_ID_10013259, PRODUCT_ID_10150217, PRODUCT_ID_10615653, PRODUCT_ID_10013858, PRODUCT_ID_10141809, PRODUCT_ID_10314251, PRODUCT_ID_10604486, BONUS_BUY_NOTE_A007, PRODUCT_ID_10319413, PRODUCT_ID_10013052, BONUS_BUY_NOTE_A011, PRODUCT_ID_10141810, PRODUCT_ID_10015255, PRODUCT_ID_10141174, PRODUCT_ID_10008690, PRODUCT_ID_10008740, PRODUCT_ID_10600091, PRODUCT_ID_10009085, PRODUCT_ID_10162336, PRODUCT_ID_10013811, PRODUCT_ID_10013935, PRODUCT_ID_10020624, PRODUCT_ID_10020564, PRODUCT_ID_10613667, PRODUCT_ID_10141374, PRODUCT_ID_10142094, PRODUCT_ID_10142044, PRODUCT_ID_10303865, PRODUCT_ID_10014861, PRODUCT_ID_10013857, PRODUCT_ID_10016836, PRODUCT_ID_10020176, PRODUCT_ID_10012913, PRODUCT_ID_10230785, PRODUCT_ID_10170637, PRODUCT_ID_10308404, PRODUCT_ID_10184019, PRODUCT_ID_10629512, PRODUCT_ID_10013932, PRODUCT_ID_10160482, PRODUCT_ID_10194725, PRODUCT_ID_10141364, PRODUCT_ID_10013397, PRODUCT_ID_10195097, PRODUCT_ID_10181145, PRODUCT_ID_10620827, PRODUCT_ID_10020563, PRODUCT_ID_10140892, PRODUCT_ID_10197711, PRODUCT_ID_10162282, PRODUCT_ID_10224131, PRODUCT_ID_10314278, PRODUCT_ID_10224132, PRODUCT_ID_10142277, PRODUCT_ID_10197447, PRODUCT_ID_10332741, PRODUCT_ID_10311506, PRODUCT_ID_10406482, PRODUCT_ID_10324916, PRODUCT_ID_10198083, PRODUCT_ID_10013980, PRODUCT_ID_10011506, PRODUCT_ID_10161757, PRODUCT_ID_10150434, PRODUCT_ID_10327495, PRODUCT_ID_10008624, PRODUCT_ID_10013659, PRODUCT_ID_10627936, PRODUCT_ID_10011147, PRODUCT_ID_10266343, PRODUCT_ID_10624767, PRODUCT_ID_10010117, PRODUCT_ID_10193761, PRODUCT_ID_10223994, PRODUCT_ID_10192798, PRODUCT_ID_10010079, PRODUCT_ID_10236113, PRODUCT_ID_10142030, PRODUCT_ID_10014498, PRODUCT_ID_10601173, BONUS_BUY_NOTE_A018, PRODUCT_ID_10181026, PRODUCT_ID_10056598, PRODUCT_ID_10196624, PRODUCT_ID_10012928, PRODUCT_ID_10015748, PRODUCT_ID_10020670, PRODUCT_ID_10142218, PRODUCT_ID_10223991, PRODUCT_ID_10010158, PRODUCT_ID_10406891, PRODUCT_ID_10007821, PRODUCT_ID_10160567, PRODUCT_ID_10008696, PRODUCT_ID_10193847, PRODUCT_ID_10600304, PRODUCT_ID_10161831, PRODUCT_ID_10170930, PRODUCT_ID_10011400, PRODUCT_ID_10617625, PRODUCT_ID_10170503, PRODUCT_ID_10195893, PRODUCT_ID_10016022, PRODUCT_ID_10604480, PRODUCT_ID_10012822, PRODUCT_ID_10236111, PRODUCT_ID_10181117, PRODUCT_ID_10007955, PRODUCT_ID_10018975, PRODUCT_ID_10141429, PRODUCT_ID_10170650, PRODUCT_ID_10615687, PRODUCT_ID_10008607, PRODUCT_ID_10009044, PRODUCT_ID_10197483, PRODUCT_ID_10170265, PRODUCT_ID_10086322, PRODUCT_ID_10160009, PRODUCT_ID_10601169, PRODUCT_ID_10194776, PRODUCT_ID_10223995, PRODUCT_ID_10171306, PRODUCT_ID_10192537, PRODUCT_ID_10140939, PRODUCT_ID_10013657, PRODUCT_ID_10181143, PRODUCT_ID_10161716, PRODUCT_ID_10601691, PRODUCT_ID_10162461, PRODUCT_ID_10013764, PRODUCT_ID_10015011, PRODUCT_ID_10617348, PRODUCT_ID_10142189, PRODUCT_ID_10613668, PRODUCT_ID_10628014, P ...
# training data did not have the following fields: PRODUCT_ID_10142123, PRODUCT_ID_10018164, PRODUCT_ID_10167098, PRODUCT_ID_10020602, PRODUCT_ID_10009271, BONUS_BUY_NOTE_A008, PRODUCT_ID_10142217, PRODUCT_ID_10017353, PRODUCT_ID_10198098, PRODUCT_ID_10141411, PRODUCT_ID_10015340, PRODUCT_ID_10167100, PRODUCT_ID_10018581, PRODUCT_ID_10018505, PRODUCT_ID_10198163, PRODUCT_ID_10020133, PRODUCT_ID_10167207, PRODUCT_ID_10198110, PRODUCT_ID_10198019, PRODUCT_ID_10638799, PRODUCT_ID_10162343, PRODUCT_ID_10334814, PRODUCT_ID_10198224, PRODUCT_ID_10192263, PRODUCT_ID_10141087, PRODUCT_ID_10198223, PRODUCT_ID_10192800, PRODUCT_ID_10613380, PRODUCT_ID_10601140, PRODUCT_ID_10171346, PRODUCT_ID_10334744, PRODUCT_ID_10333125, PRODUCT_ID_10014887, PRODUCT_ID_10197682, PRODUCT_ID_10195005, PRODUCT_ID_10142167, PRODUCT_ID_10181046, PRODUCT_ID_10018752, PRODUCT_ID_10602566, PRODUCT_ID_10007959, PRODUCT_ID_10010280, PRODUCT_ID_10016764, PRODUCT_ID_10603568, PRODUCT_ID_10020749, PRODUCT_ID_10161780, PRODUCT_ID_10197683, PRODUCT_ID_10142499, PRODUCT_ID_10198298, PRODUCT_ID_10017351, PRODUCT_ID_10008877, PRODUCT_ID_10008240, PRODUCT_ID_10013552, PRODUCT_ID_10321999, PRODUCT_ID_10181048, PRODUCT_ID_10198225, PRODUCT_ID_10198245, PRODUCT_ID_10141807, PRODUCT_ID_10290082, PRODUCT_ID_10013007, PRODUCT_ID_10012935, PRODUCT_ID_10013456, PRODUCT_ID_10142170, PRODUCT_ID_10142169, PRODUCT_ID_10181049, PRODUCT_ID_10314252, PRODUCT_ID_10181047, PRODUCT_ID_10624398, PRODUCT_ID_10020131, PRODUCT_ID_10171139, PRODUCT_ID_10620222, PRODUCT_ID_10142168, PRODUCT_ID_10195918, PRODUCT_ID_10008569, PRODUCT_ID_10010075, PRODUCT_ID_10626197, PRODUCT_ID_10161324, PRODUCT_ID_10171228, PRODUCT_ID_10167101, PRODUCT_ID_10252767, PRODUCT_ID_10171076, PRODUCT_ID_10640563, PRODUCT_ID_10162341, PRODUCT_ID_10406495, PRODUCT_ID_10013919, PRODUCT_ID_10011399, PRODUCT_ID_10197084, PRODUCT_ID_10629912
