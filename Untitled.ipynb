# %%
import pandas as pd
import numpy as np

# %%
## Data that has sales
df_sales = pd.read_csv('./dataset/sale_data.csv',parse_dates=['CALDAY'])

# %%
df_sales.head()
# Out:
#       CALDAY  PRODUCT_ID STORE_ID  SALE_QTY
# 0 2024-09-30    10007930     6773        10
# 1 2024-09-22    10007925     6332        37
# 2 2024-09-22    10007927     6379        14
# 3 2024-09-22    10142300     6955        19
# 4 2024-09-29    10007925     6754        14

# %%
df_sales.describe()
# Out:
#                               CALDAY    PRODUCT_ID       SALE_QTY
# count                         242840  2.428400e+05  242840.000000
# mean   2024-09-27 09:42:04.328775936  1.023123e+07       1.954575
# min              2024-09-21 00:00:00  1.000792e+07     -53.000000
# 25%              2024-09-24 00:00:00  1.014177e+07       1.000000
# 50%              2024-09-28 00:00:00  1.018085e+07       1.000000
# 75%              2024-10-01 00:00:00  1.025038e+07       2.000000
# max              2024-10-04 00:00:00  1.063985e+07     665.000000
# std                              NaN  1.989476e+05       4.007052

# %%
## Inventory data
df_inventory = pd.read_csv('./dataset/last_month_inventory.csv',parse_dates=['CALDAY'])

# %%
df_inventory.head()
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  STOCK
# 0    10198041     3965 2024-10-03   45.0
# 1    10198041     3205 2024-10-01   28.0
# 2    10198167     3287 2024-10-01   18.0
# 3    10197716     3327 2024-10-01    3.0
# 4    10198080     2242 2024-10-04    9.0

# %%
df_inventory.describe()
# Out:
#          PRODUCT_ID                         CALDAY          STOCK
# count  3.279030e+05                         327903  327888.000000
# mean   1.021475e+07  2024-10-02 12:01:16.808080384      30.850272
# min    1.000792e+07            2024-10-01 00:00:00   -2268.000000
# 25%    1.014220e+07            2024-10-02 00:00:00       6.000000
# 50%    1.017131e+07            2024-10-03 00:00:00      12.000000
# 75%    1.019820e+07            2024-10-04 00:00:00      24.000000
# max    1.063985e+07            2024-10-04 00:00:00    6982.000000
# std    1.708520e+05                            NaN     120.915344

# %%
## Check both the data has same date range

# %%
print("Sales Data Date Range")
print(f"Min date : {df_sales.CALDAY.min()}")
print(f"Max date : {df_sales.CALDAY.max()}")
# Out:
# Sales Data Date Range
# Min date : 2024-09-21 00:00:00
# Max date : 2024-10-04 00:00:00

# %%
print("Inventory Data Date Range")
print(f"Min date : {df_inventory.CALDAY.min()}")
print(f"Max date : {df_inventory.CALDAY.max()}")
# Out:
# Inventory Data Date Range
# Min date : 2024-10-01 00:00:00
# Max date : 2024-10-04 00:00:00

# %%
## Getting average sales
df_base = df_sales.groupby(['PRODUCT_ID', 'STORE_ID', 'CALDAY']).agg(TOTAL_BASE_SALE_QTY=('SALE_QTY', 'sum')).reset_index()

# %%
df_base.head()
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY
# 0    10007925     2012 2024-09-21                    9
# 1    10007925     2012 2024-09-22                   19
# 2    10007925     2012 2024-09-23                    5
# 3    10007925     2012 2024-09-24                    5
# 4    10007925     2012 2024-09-25                    5

# %%
min_date = '2024-10-01'
max_date = '2024-10-04'

# %%
df_base_filtered = df_base[(df_base['CALDAY'] <=max_date) & (df_base['CALDAY'] >=min_date) ]

# %%
df_base_filtered.head(5)
# Out:
#     PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY
# 10    10007925     2012 2024-10-01                   10
# 11    10007925     2012 2024-10-02                   21
# 12    10007925     2012 2024-10-03                    6
# 20    10007925     2014 2024-10-01                    3
# 21    10007925     2014 2024-10-02                    9

# %%
## Merge the inventory data with the above date

# %%
combined_df = pd.merge(df_base_filtered, df_inventory, how='left', on=['STORE_ID', 'PRODUCT_ID', 'CALDAY'])
## the how='left' was 'right' originally and was causing error

# %%
combined_df.head()
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY   STOCK
# 0    10007925     2012 2024-10-01                   10   987.0
# 1    10007925     2012 2024-10-02                   21   966.0
# 2    10007925     2012 2024-10-03                    6   960.0
# 3    10007925     2014 2024-10-01                    3  1918.0
# 4    10007925     2014 2024-10-02                    9  1909.0

# %%
combined_df['is_month_start'] = combined_df['CALDAY'].dt.is_month_start.astype(int)

# %%
combined_df['is_holiday'] = combined_df['CALDAY'].dt.weekday.isin([5, 6]).astype(int)

# %%
combined_df.head()
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY   STOCK  \
# 0    10007925     2012 2024-10-01                   10   987.0
# 1    10007925     2012 2024-10-02                   21   966.0
# 2    10007925     2012 2024-10-03                    6   960.0
# 3    10007925     2014 2024-10-01                    3  1918.0
# 4    10007925     2014 2024-10-02                    9  1909.0
#
#    is_month_start  is_holiday
# 0               1           0
# 1               0           0
# 2               0           0
# 3               1           0
# 4               0           0

# %%
combined_df['previous_day_sales'] = combined_df.groupby(['STORE_ID', 'PRODUCT_ID'])['TOTAL_BASE_SALE_QTY'].shift(1)

# %%
combined_df['previous_day_sales'] = combined_df.groupby(['STORE_ID', 'PRODUCT_ID'])['previous_day_sales'].transform(lambda x: x.fillna(x.mean()))

# %%
combined_df.head()
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY   STOCK  \
# 0    10007925     2012 2024-10-01                   10   987.0
# 1    10007925     2012 2024-10-02                   21   966.0
# 2    10007925     2012 2024-10-03                    6   960.0
# 3    10007925     2014 2024-10-01                    3  1918.0
# 4    10007925     2014 2024-10-02                    9  1909.0
#
#    is_month_start  is_holiday  previous_day_sales
# 0               1           0                15.5
# 1               0           0                10.0
# 2               0           0                21.0
# 3               1           0                 6.0
# 4               0           0                 3.0

# %%
combined_df.isna().sum()
# Out:
# PRODUCT_ID                 0
# STORE_ID                   0
# CALDAY                     0
# TOTAL_BASE_SALE_QTY        0
# STOCK                      5
# is_month_start             0
# is_holiday                 0
# previous_day_sales     20713
# dtype: int64

# %%
combined_df = combined_df.dropna()

# %%
## Removing outlier

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(combined_df.TOTAL_BASE_SALE_QTY.values)

# %%
combined_df = combined_df[combined_df['TOTAL_BASE_SALE_QTY']>=0]

# %%
def handle_outliers(train, column, method='remove'):
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = train[column].quantile(0.05)
    Q3 = train[column].quantile(0.95)
    IQR = Q3 - Q1

    # Define the bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    if method == 'remove':
        # Remove outliers
        train = train[(train[column] >= lower_bound) & (train[column] <= upper_bound)]
    elif method == 'cap':
        # Cap outliers
        train[column] = train[column].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

    return train

# %%
combined_df = handle_outliers(combined_df,'TOTAL_BASE_SALE_QTY','remove')

# %%
def one_hot_encode(df, columns):
    """
    Perform one-hot encoding on specified columns in a DataFrame.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame.
    columns (list): List of columns to be one-hot encoded.
    
    Returns:
    pd.DataFrame: The DataFrame with one-hot encoded columns.
    """
    # Perform one-hot encoding using pd.get_dummies
    df_encoded = pd.get_dummies(df, columns=columns, drop_first=True)
    
    return df_encoded

# %%
ohe_f = ['STORE_ID', 'PRODUCT_ID']

# %%
df_encoded = one_hot_encode(combined_df,ohe_f)

# %%
df_encoded.head(3)
# Out:
#       CALDAY  TOTAL_BASE_SALE_QTY   STOCK  is_month_start  is_holiday  \
# 0 2024-10-01                   10   987.0               1           0
# 2 2024-10-03                    6   960.0               0           0
# 3 2024-10-01                    3  1918.0               1           0
#
#    previous_day_sales  STORE_ID_2014  STORE_ID_2015  STORE_ID_2018  \
# 0                15.5          False          False          False
# 2                21.0          False          False          False
# 3                 6.0           True          False          False
#
#    STORE_ID_2020  ...  PRODUCT_ID_10625441  PRODUCT_ID_10625444  \
# 0          False  ...                False                False
# 2          False  ...                False                False
# 3          False  ...                False                False
#
#    PRODUCT_ID_10625446  PRODUCT_ID_10625447  PRODUCT_ID_10625448  \
# 0                False                False                False
# 2                False                False                False
# 3                False                False                False
#
#    PRODUCT_ID_10629752  PRODUCT_ID_10638471  PRODUCT_ID_10639850  \
# 0                False                False                False
# 2                False                False                False
# 3                False                False                False
#
#    PRODUCT_ID_10639851  PRODUCT_ID_10639853
# 0                False                False
# 2                False                False
# 3                False                False
#
# [3 rows x 874 columns]

# %%
print(df_encoded.isna().sum())
# Out:
# CALDAY                 0
# TOTAL_BASE_SALE_QTY    0
# STOCK                  0
# is_month_start         0
# is_holiday             0
#                       ..
# PRODUCT_ID_10629752    0
# PRODUCT_ID_10638471    0
# PRODUCT_ID_10639850    0
# PRODUCT_ID_10639851    0
# PRODUCT_ID_10639853    0
# Length: 874, dtype: int64

# %%
## training the model

# %%
from xgboost import XGBRegressor
import torch

# %%
## Setting up the gpu

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 3060 Laptop GPU'

# %%
# manual train
date_range = '2024-10-04'
train_df = df_encoded.loc[df_encoded.CALDAY < date_range]
test_df = df_encoded.loc[df_encoded.CALDAY >= date_range]

# %%
X_train, y_train = train_df.drop(['TOTAL_BASE_SALE_QTY','CALDAY'],axis=1), train_df['TOTAL_BASE_SALE_QTY']
X_test, y_test = test_df.drop(['TOTAL_BASE_SALE_QTY','CALDAY'],axis=1), test_df['TOTAL_BASE_SALE_QTY']

# %%
## Model training
model = XGBRegressor(tree_method="hist", device="cuda", enable_categorical=True)

# %%
# %%time
model.fit(X_train,y_train)
# Out:
# CPU times: total: 7.61 s
# Wall time: 3.26 s
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model.score(X_test,y_test)
# Out:
# C:\Users\ASUS\anaconda3\envs\ocr_env\lib\site-packages\xgboost\core.py:158: UserWarning: [22:55:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# 0.2591869831085205

# %%
test_df['predictions'] = model.predict(X_test)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3152\3971915116.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['predictions'] = model.predict(X_test)

# %%
test_df.head()
# Out:
#        CALDAY  TOTAL_BASE_SALE_QTY   STOCK  is_month_start  is_holiday  \
# 11 2024-10-04                    2   539.0               0           0
# 15 2024-10-04                   10  5975.0               0           0
# 23 2024-10-04                    2    87.0               0           0
# 26 2024-10-04                    1    30.0               0           0
# 32 2024-10-04                    9  2165.0               0           0
#
#     previous_day_sales  STORE_ID_2014  STORE_ID_2015  STORE_ID_2018  \
# 11                 2.0          False          False           True
# 15                 8.0          False          False          False
# 23                 1.0          False          False          False
# 26                 2.0          False          False          False
# 32                12.0          False          False          False
#
#     STORE_ID_2020  ...  PRODUCT_ID_10625444  PRODUCT_ID_10625446  \
# 11          False  ...                False                False
# 15           True  ...                False                False
# 23          False  ...                False                False
# 26          False  ...                False                False
# 32          False  ...                False                False
#
#     PRODUCT_ID_10625447  PRODUCT_ID_10625448  PRODUCT_ID_10629752  \
# 11                False                False                False
# 15                False                False                False
# 23                False                False                False
# 26                False                False                False
# 32                False                False                False
#
#     PRODUCT_ID_10638471  PRODUCT_ID_10639850  PRODUCT_ID_10639851  \
# 11                False                False                False
# 15                False                False                False
# 23                False                False                False
# 26                False                False                False
# 32                False                False                False
#
#     PRODUCT_ID_10639853  predictions
# 11                False     4.285492
# 15                False     4.872941
# 23                False     1.659512
# 26                False     2.006128
# 32                False     4.234241
#
# [5 rows x 875 columns]

# %%
def MAPE_EVAL(df_max, col):
    APE = []
    for index, row in df_max.iterrows():
        # Handle case where actual sales (SALE_QTY) is zero
        actual_sales = row['TOTAL_BASE_SALE_QTY'] if row['TOTAL_BASE_SALE_QTY'] != 0 else 1
        
        # Calculate percentage error without rounding off
        if row[col] is not None:
            per_err = (row['TOTAL_BASE_SALE_QTY'] - row[col]) / actual_sales
        else:
            per_err = (row[col] - row['TOTAL_BASE_SALE_QTY'])
        
        per_err = np.abs(per_err)
        APE.append(per_err)

    MAPE = np.sum(APE) / len(APE)

    # Print the MAPE value and percentage
    print(f'''
    MAPE   : {MAPE}
    MAPE % : {MAPE * 100} %
    ''')

# %%
MAPE_EVAL(test_df,'predictions')
# Out:
#     MAPE   : 0.6087812322531
#     MAPE % : 60.87812322531 %
