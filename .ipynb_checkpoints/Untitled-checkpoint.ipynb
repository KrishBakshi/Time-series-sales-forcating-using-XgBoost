# %%
import pandas as pd
import numpy as np

# %%
## Data that has sales
df_sales = pd.read_excel('./dataset/sales_data_sept.xlsx',parse_dates=['CALDAY'])

# %%
df_sales.head()
# Out:
#       CALDAY  PRODUCT_ID STORE_ID  SALE_QTY
# 0 2024-09-25    10008076     2A01       0.0
# 1 2024-09-25    10198224     2A01       0.0
# 2 2024-09-25    10018505     2A01       0.0
# 3 2024-09-25    10011205     2A01       0.0
# 4 2024-09-25    10012920     2A01       3.0

# %%
df_sales.describe()
# Out:
#                               CALDAY    PRODUCT_ID       SALE_QTY
# count                         326882  3.268820e+05  326882.000000
# mean   2024-09-15 09:07:02.442349312  1.017962e+07       1.780536
# min              2024-09-01 00:00:00  1.000504e+07      -4.000000
# 25%              2024-09-08 00:00:00  1.001366e+07       1.000000
# 50%              2024-09-15 00:00:00  1.014255e+07       1.000000
# 75%              2024-09-23 00:00:00  1.022399e+07       2.000000
# max              2024-09-30 00:00:00  1.064056e+07    4850.000000
# std                              NaN  1.912611e+05      19.996163

# %%
## Inventory data
df_inventory = pd.read_excel('./dataset/inventory_data_sept.xlsx',parse_dates=['CALDAY'])

# %%
df_inventory.head()
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  STOCK
# 0    10326501     3579 2024-09-06    0.0
# 1    10162292     3579 2024-09-06    3.0
# 2    10161733     3579 2024-09-06    5.0
# 3    10014615     3579 2024-09-06    2.0
# 4    10160009     3579 2024-09-06    3.0

# %%
df_inventory.describe()
# Out:
#          PRODUCT_ID                      CALDAY          STOCK
# count  5.000000e+05                      500000  499959.000000
# mean   1.018641e+07  2024-09-15 14:35:20.486400      13.889438
# min    1.000504e+07         2024-09-01 00:00:00   -2999.000000
# 25%    1.001674e+07         2024-09-08 00:00:00       3.000000
# 50%    1.016241e+07         2024-09-16 00:00:00       7.000000
# 75%    1.023258e+07         2024-09-23 00:00:00      13.000000
# max    1.064056e+07         2024-09-30 00:00:00    8073.000000
# std    1.834185e+05                         NaN      57.930087

# %%
## Check both the data has same date range

# %%
print("Sales Data Date Range")
print(f"Min date : {df_sales.CALDAY.min()}")
print(f"Max date : {df_sales.CALDAY.max()}")
# Out:
# Sales Data Date Range
# Min date : 2024-09-01 00:00:00
# Max date : 2024-09-30 00:00:00

# %%
print("Inventory Data Date Range")
print(f"Min date : {df_inventory.CALDAY.min()}")
print(f"Max date : {df_inventory.CALDAY.max()}")
# Out:
# Inventory Data Date Range
# Min date : 2024-09-01 00:00:00
# Max date : 2024-09-30 00:00:00

# %%
## Getting average sales
df_base = df_sales.groupby(['PRODUCT_ID', 'STORE_ID', 'CALDAY']).agg(TOTAL_BASE_SALE_QTY=('SALE_QTY', 'sum')).reset_index()

# %%
df_base.head()
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY
# 0    10005045     3427 2024-09-23                  1.0
# 1    10005045     3671 2024-09-11                  1.0
# 2    10005045     3671 2024-09-17                  3.0
# 3    10005045     3671 2024-09-27                  1.0
# 4    10005045     3770 2024-09-21                  1.0

# %%
min_date = '2024-09-01'
max_date = '2024-09-30'

# %%
df_base_filtered = df_base[(df_base['CALDAY'] <=max_date) & (df_base['CALDAY'] >=min_date) ]

# %%
df_base_filtered.head(5)
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY
# 0    10005045     3427 2024-09-23                  1.0
# 1    10005045     3671 2024-09-11                  1.0
# 2    10005045     3671 2024-09-17                  3.0
# 3    10005045     3671 2024-09-27                  1.0
# 4    10005045     3770 2024-09-21                  1.0

# %%
## Merge the inventory data with the above date

# %%
combined_df = pd.merge(df_base_filtered, df_inventory, how='left', on=['STORE_ID', 'PRODUCT_ID', 'CALDAY'])
## the how='left' was 'right' originally and was causing error

# %%
combined_df.head()
# Out:
#    PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY  STOCK
# 0    10005045     3427 2024-09-23                  1.0    NaN
# 1    10005045     3671 2024-09-11                  1.0    3.0
# 2    10005045     3671 2024-09-17                  3.0    0.0
# 3    10005045     3671 2024-09-27                  1.0    NaN
# 4    10005045     3770 2024-09-21                  1.0    NaN

# %%
combined_df.describe()
# Out:
#          PRODUCT_ID                         CALDAY  TOTAL_BASE_SALE_QTY  \
# count  3.268820e+05                         326882        326882.000000
# mean   1.017962e+07  2024-09-15 09:07:02.442349568             1.780536
# min    1.000504e+07            2024-09-01 00:00:00            -4.000000
# 25%    1.001366e+07            2024-09-08 00:00:00             1.000000
# 50%    1.014255e+07            2024-09-15 00:00:00             1.000000
# 75%    1.022399e+07            2024-09-23 00:00:00             2.000000
# max    1.064056e+07            2024-09-30 00:00:00          4850.000000
# std    1.912611e+05                            NaN            19.996163
#
#               STOCK
# count  55798.000000
# mean      25.152829
# min    -2999.000000
# 25%        5.000000
# 50%       11.000000
# 75%       22.000000
# max     7871.000000
# std      107.179953

# %%
## Checking features 
combined_df.isna().sum()
# Out:
# PRODUCT_ID                  0
# STORE_ID                    0
# CALDAY                      0
# TOTAL_BASE_SALE_QTY         0
# STOCK                  271084
# dtype: int64

# %%
## Drop the data that is not common in both the files
combined_df = combined_df.dropna()

# %%
combined_df['is_month_start'] = combined_df['CALDAY'].dt.is_month_start.astype(int)

# %%
combined_df['is_month_end'] = combined_df['CALDAY'].dt.is_month_end.astype(int)

# %%
combined_df['is_holiday'] = combined_df['CALDAY'].dt.weekday.isin([5, 6]).astype(int)

# %%
combined_df.head()
# Out:
#     PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY  STOCK  \
# 1     10005045     3671 2024-09-11                  1.0    3.0
# 2     10005045     3671 2024-09-17                  3.0    0.0
# 9     10005045     3798 2024-09-27                  1.0    2.0
# 31    10005045     5198 2024-09-11                  1.0    2.0
# 32    10005045     5330 2024-09-03                  1.0    9.0
#
#     is_month_start  is_month_end  is_holiday
# 1                0             0           0
# 2                0             0           0
# 9                0             0           0
# 31               0             0           0
# 32               0             0           0

# %%
combined_df['previous_day_sales'] = combined_df.groupby(['STORE_ID', 'PRODUCT_ID'])['TOTAL_BASE_SALE_QTY'].shift(1)

# %%
combined_df.isna().sum()
# Out:
# PRODUCT_ID                 0
# STORE_ID                   0
# CALDAY                     0
# TOTAL_BASE_SALE_QTY        0
# STOCK                      0
# is_month_start             0
# is_month_end               0
# is_holiday                 0
# previous_day_sales     34445
# dtype: int64

# %%
# combined_df[(combined_df['PRODUCT_ID']== 10005045) & (combined_df['STORE_ID']== '3671')]

# %%
combined_df['previous_day_sales'] = combined_df.groupby(['STORE_ID', 'PRODUCT_ID'])['previous_day_sales'].transform(lambda x: x.fillna(x.mean()))

# %%
combined_df.head()
# Out:
#     PRODUCT_ID STORE_ID     CALDAY  TOTAL_BASE_SALE_QTY  STOCK  \
# 1     10005045     3671 2024-09-11                  1.0    3.0
# 2     10005045     3671 2024-09-17                  3.0    0.0
# 9     10005045     3798 2024-09-27                  1.0    2.0
# 31    10005045     5198 2024-09-11                  1.0    2.0
# 32    10005045     5330 2024-09-03                  1.0    9.0
#
#     is_month_start  is_month_end  is_holiday  previous_day_sales
# 1                0             0           0                 1.0
# 2                0             0           0                 1.0
# 9                0             0           0                 NaN
# 31               0             0           0                 NaN
# 32               0             0           0                 1.0

# %%
combined_df.isna().sum()
# Out:
# PRODUCT_ID                 0
# STORE_ID                   0
# CALDAY                     0
# TOTAL_BASE_SALE_QTY        0
# STOCK                      0
# is_month_start             0
# is_month_end               0
# is_holiday                 0
# previous_day_sales     21504
# dtype: int64

# %%
len(combined_df['PRODUCT_ID'].unique())
# Out:
# 1633

# %%
len(combined_df['STORE_ID'].unique())
# Out:
# 80

# %%
combined_df = combined_df.dropna()

# %%
## Removing outlier

# %%
import matplotlib.pyplot as plt

# %%
# Create a figure for two subplots
plt.figure(figsize=(12, 6))

# First subplot: Line plot of 'Sales' over 'CALDAY'
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st plot
plt.plot(combined_df.TOTAL_BASE_SALE_QTY.values, color='b')
plt.title('TOTAL_BASE_SALE_QTY')

# Second subplot: Bar plot of 'Profit' over 'CALDAY'
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd plot
plt.plot(combined_df.STOCK.values, color='g')
plt.title('STOCK')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %%
combined_df = combined_df[combined_df['TOTAL_BASE_SALE_QTY']>=0]

# %%
# combined_df = combined_df[combined_df['STOCK']>=0]

# %%
def handle_outliers(train, column, method='remove'):
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = train[column].quantile(0.05)
    Q3 = train[column].quantile(0.95)
    IQR = Q3 - Q1

    # Define the bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    if method == 'remove':
        # Remove outliers
        train = train[(train[column] >= lower_bound) & (train[column] <= upper_bound)]
    elif method == 'cap':
        # Cap outliers
        train[column] = train[column].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

    return train

# %%
combined_df = handle_outliers(combined_df,'TOTAL_BASE_SALE_QTY','remove')

# %%
# combined_df = handle_outliers(combined_df,'STOCK','remove')

# %%
def one_hot_encode(df, columns):
    """
    Perform one-hot encoding on specified columns in a DataFrame.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame.
    columns (list): List of columns to be one-hot encoded.
    
    Returns:
    pd.DataFrame: The DataFrame with one-hot encoded columns.
    """
    # Perform one-hot encoding using pd.get_dummies
    df_encoded = pd.get_dummies(df, columns=columns, drop_first=True)
    
    return df_encoded

# %%
ohe_f = ['STORE_ID', 'PRODUCT_ID']

# %%
df_encoded = one_hot_encode(combined_df,ohe_f)

# %%
df_encoded.head(3)
# Out:
#        CALDAY  TOTAL_BASE_SALE_QTY  STOCK  is_month_start  is_month_end  \
# 1  2024-09-11                  1.0    3.0               0             0
# 2  2024-09-17                  3.0    0.0               0             0
# 32 2024-09-03                  1.0    9.0               0             0
#
#     is_holiday  previous_day_sales  STORE_ID_2A19  STORE_ID_2A85  \
# 1            0                 1.0          False          False
# 2            0                 1.0          False          False
# 32           0                 1.0          False          False
#
#     STORE_ID_2AC7  ...  PRODUCT_ID_10639851  PRODUCT_ID_10639853  \
# 1           False  ...                False                False
# 2           False  ...                False                False
# 32          False  ...                False                False
#
#     PRODUCT_ID_10639861  PRODUCT_ID_10640291  PRODUCT_ID_10640295  \
# 1                 False                False                False
# ...

# %%
print(df_encoded.isna().sum())
# Out:
# CALDAY                 0
# TOTAL_BASE_SALE_QTY    0
# STOCK                  0
# is_month_start         0
# is_month_end           0
#                       ..
# PRODUCT_ID_10640381    0
# PRODUCT_ID_10640382    0
# PRODUCT_ID_10640388    0
# PRODUCT_ID_10640562    0
# PRODUCT_ID_10640563    0
# Length: 1359, dtype: int64

# %%
## training the model

# %%
from xgboost import XGBRegressor
import torch

# %%
## Setting up the gpu

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 3060 Laptop GPU'

# %%
# manual train
date_range = '2024-09-25'
train_df = df_encoded.loc[df_encoded.CALDAY < date_range]
test_df = df_encoded.loc[df_encoded.CALDAY >= date_range]

# %%
X_train, y_train = train_df.drop(['TOTAL_BASE_SALE_QTY','CALDAY'],axis=1), train_df['TOTAL_BASE_SALE_QTY']
X_test, y_test = test_df.drop(['TOTAL_BASE_SALE_QTY','CALDAY'],axis=1), test_df['TOTAL_BASE_SALE_QTY']

# %%
## Model training
model = XGBRegressor(tree_method="hist", device="cuda", enable_categorical=True)

# %%
# %%time
model.fit(X_train,y_train)
# Out:
# CPU times: total: 9.58 s
# Wall time: 4.97 s
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model.score(X_test,y_test)
# Out:
# C:\Users\ASUS\anaconda3\envs\ocr_env\lib\site-packages\xgboost\core.py:158: UserWarning: [16:43:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# 0.13547255950101322

# %%
test_df['predictions'] = model.predict(X_test)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16368\3971915116.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['predictions'] = model.predict(X_test)

# %%
test_df.head()
# Out:
#         CALDAY  TOTAL_BASE_SALE_QTY  STOCK  is_month_start  is_month_end  \
# 344 2024-09-29                  1.0    7.0               0             0
# 354 2024-09-25                  1.0    2.0               0             0
# 396 2024-09-30                  1.0    6.0               0             1
# 406 2024-09-25                  1.0    1.0               0             0
# 430 2024-09-27                  1.0   22.0               0             0
#
#      is_holiday  previous_day_sales  STORE_ID_2A19  STORE_ID_2A85  \
# 344           1                 2.0          False          False
# 354           0                 1.0          False          False
# 396           0                 2.0          False          False
# 406           0                 1.0          False          False
# 430           0                 1.0           True          False
#
#      STORE_ID_2AC7  ...  PRODUCT_ID_10639853  PRODUCT_ID_10639861  \
# ...

# %%
def MAPE_EVAL(df_max, col):
    APE = []
    for index, row in df_max.iterrows():
        # Handle case where actual sales (SALE_QTY) is zero
        actual_sales = row['TOTAL_BASE_SALE_QTY'] if row['TOTAL_BASE_SALE_QTY'] != 0 else 1
        
        # Calculate percentage error without rounding off
        if row[col] is not None:
            per_err = (row['TOTAL_BASE_SALE_QTY'] - row[col]) / actual_sales
        else:
            per_err = (row[col] - row['TOTAL_BASE_SALE_QTY'])
        
        per_err = np.abs(per_err)
        APE.append(per_err)

    MAPE = np.sum(APE) / len(APE)

    # Print the MAPE value and percentage
    print(f'''
    MAPE   : {MAPE}
    MAPE % : {MAPE * 100} %
    ''')

# %%
MAPE_EVAL(test_df,'predictions')
# Out:
#     MAPE   : 0.5984147797780293
#     MAPE % : 59.841477977802924 %
